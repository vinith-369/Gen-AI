# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from langgraph.graph import StateGraph, START, END, add_messages
from langgraph.types import Command, interrupt
from typing import TypedDict, Annotated, List
from langgraph.checkpoint.memory import MemorySaver
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
import uuid

# %%
groq_api = "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"

llm = ChatGroq(model="llama-3.1-8b-instant", api_key=groq_api)

# %%
class State(TypedDict): 
    linkedin_topic: str
    generated_post: Annotated[List[str], add_messages]
    human_feedback: Annotated[List[str], add_messages]



def model(state: State): 
    """ Here, we're using the LLM to generate a LinkedIn post with human feedback incorporated """

    print("[model] Generating content")
    linkedin_topic = state["linkedin_topic"]
    feedback = state["human_feedback"] if "human_feedback" in state else ["No Feedback yet"]


    # Here, we define the prompt 

    prompt = f"""

        LinkedIn Topic: {linkedin_topic}
        Human Feedback: {feedback[-1] if feedback else "No feedback yet"}

        Generate a structured and well-written LinkedIn post based on the given topic.

        Consider previous human feedback to refine the reponse. 
    """

    response = llm.invoke([
        SystemMessage(content="You are an expert LinkedIn content writer"), 
        HumanMessage(content=prompt)
    ])

    geneated_linkedin_post = response.content

    print(f"[model_node] Generated post:\n{geneated_linkedin_post}\n")

    return {
       "generated_post": [AIMessage(content=geneated_linkedin_post)] , 
       "human_feedback": feedback
    }

def human_node(state: State): 
    """Human Intervention node - loops back to model unless input is done"""

    print("\n [human_node] awaiting human feedback...")

    generated_post = state["generated_post"]

    # Interrupt to get user feedback

    user_feedback = interrupt(
        {
            "generated_post": generated_post, 
            "message": "Provide feedback or type 'done' to finish"
        }
    )

    print(f"[human_node] Received human feedback: {user_feedback}")

    # If user types "done", transition to END node
    if user_feedback.lower() == "done": 
        return Command(update={"human_feedback": state["human_feedback"] + ["Finalised"]}, goto="end_node")

    # Otherwise, update feedback and return to model for re-generation
    return Command(update={"human_feedback": state["human_feedback"] + [user_feedback]}, goto="model")


def end_node(state: State): 
    """ Final node """
    print("\n[end_node] Process finished")
    print("Final Generated Post:", state["generated_post"][-1])
    print("Final Human Feedback", state["human_feedback"])
    return {"generated_post": state["generated_post"], "human_feedback": state["human_feedback"]}


# Buiding the Graph

graph = StateGraph(State)
graph.add_node("model", model)
graph.add_node("human_node", human_node)
graph.add_node("end_node", end_node)

graph.set_entry_point("model")

# Define the flow

graph.add_edge(START, "model")
graph.add_edge("model", "human_node")

graph.set_finish_point("end_node")

# Enable Interrupt mechanism
checkpointer = MemorySaver()
app = graph.compile(checkpointer=checkpointer)

thread_config = {"configurable": {
    "thread_id": uuid.uuid4()
}}

linkedin_topic = input("Enter your LinkedIn topic: ")
initial_state = {
    "linkedin_topic": linkedin_topic, 
    "generated_post": [], 
    "human_feedback": []
}


for chunk in app.stream(initial_state, config=thread_config):
    for node_id, value in chunk.items():
        #  If we reach an interrupt, continuously ask for human feedback

        if(node_id == "__interrupt__"):
            while True: 
                user_feedback = input("Provide feedback (or type 'done' when finished): ")

                # Resume the graph execution with the user's feedback
                app.invoke(Command(resume=user_feedback), config=thread_config)

                # Exit loop if user says done
                if user_feedback.lower() == "done":
                    break
# Out:
# [model] Generating content
# [model_node] Generated post:
# **Unlock the Full Potential of AI and ML: 5 Key Strategies for Business Success**
#
# As we continue to navigate the ever-evolving landscape of Artificial Intelligence (AI) and Machine Learning (ML), it's becoming increasingly clear that these technologies hold the key to unlocking unprecedented business growth and innovation.
#
# But, with so many resources available, it can be challenging to discern what strategies are most effective in driving tangible results. That's why I've compiled the top 5 key strategies for harnessing the power of AI and ML to propel your business forward.
#
# **1. **Focus on Augmenting Human Capabilities**
#
# Rather than replacing human workers, AI and ML should be viewed as tools to enhance and augment our capabilities. By automating repetitive and mundane tasks, we can free up human resources to focus on higher-level thinking, creativity, and problem-solving.
#
# **2. **Emphasize Explainability and Transparency**
#
# As AI and ML become increasingly prevalent in our daily lives, it's essential to prioritize explainability and transparency. This means developing models that provide clear, actionable insights into their decision-making processes, allowing for greater trust and accountability.
#
# **3. **Invest in Responsible AI and ML Practices**
#
# Responsible AI and ML practices are no longer a nicety, but a necessity. This includes implementing bias detection and mitigation strategies, ensuring data quality and integrity, and prioritizing fairness and equity in AI-driven decision-making.
#
# **4. **Leverage the Power of Hybrid Intelligence**
#
# The future of AI and ML lies in hybrid intelligence – a collaboration between human and artificial intelligence. By combining the strengths of both, we can create more effective, adaptable, and innovative solutions that drive business success.
#
# **5. **Stay Ahead of the Curve with Continuous Learning**
#
# The AI and ML landscape is constantly evolving, with new breakthroughs and innovations emerging daily. To stay ahead of the curve, it's essential to commit to continuous learning and professional development, staying up-to-date with the latest trends, tools, and best practices.
#
# By implementing these 5 key strategies, you'll be well on your way to unlocking the full potential of AI and ML and driving business success in the process.
#
# **What's your experience with AI and ML? Share your thoughts and insights in the comments below!**
#
# #AI #ML #BusinessSuccess #Innovation #HybridIntelligence #ResponsibleAI #Explainability #Transparency
#
# Note: Since there is no previous human feedback, this post is designed to spark conversation and encourage engagement. I've included a call-to-action in the comments section to encourage users to share their thoughts and experiences.
#
#
#  [human_node] awaiting human feedback...
#
#  [human_node] awaiting human feedback...
# [human_node] Received human feedback: make it short
# [model] Generating content
# [model_node] Generated post:
# **Unlock the Power of AI and ML: 3 Ways to Boost Your Business**
#
# As AI and ML continue to transform industries, it's essential to stay ahead of the curve. Here are 3 ways to harness their power and take your business to the next level:
#
#  **1. Enhance Customer Experience**: AI-powered chatbots and virtual assistants can provide 24/7 support, freeing up your team to focus on high-value tasks.
#
#  **2. Predictive Analytics**: Leverage machine learning algorithms to identify trends, forecast sales, and make data-driven decisions that drive growth.
#
#  **3. Automate Repetitive Tasks**: Streamline operations with AI-driven automation tools, reducing manual labor and increasing efficiency.
#
# Start your AI and ML journey today and discover new opportunities for growth and innovation!
#
# #AI #ML #DigitalTransformation #BusinessGrowth
#
#
#  [human_node] awaiting human feedback...
#
#  [human_node] awaiting human feedback...
# [human_node] Received human feedback: make it short
# [model] Generating content
# [model_node] Generated post:
# **Unlock the Power of AI & ML: Transforming Business Outcomes**
#
# As AI and ML continue to revolutionize the way we work, it's essential to stay ahead of the curve. Here are 3 key takeaways to get you started:
#
#  **Enhance Decision Making**: Leverage data-driven insights to make informed decisions, reducing the risk of errors and increasing productivity.
#
#  **Automate Repetitive Tasks**: Free up time for strategic initiatives by automating routine tasks, improving efficiency and reducing costs.
#
#  **Future-Proof Your Business**: Stay agile and adaptable in a rapidly changing market by harnessing the power of AI and ML.
#
# What are your top priorities for implementing AI and ML in your organization? Share your thoughts in the comments below!
#
# #AI #ML #DigitalTransformation #BusinessOutcomes #Productivity #Efficiency
#
#
#  [human_node] awaiting human feedback...
#
#  [human_node] awaiting human feedback...
# [human_node] Received human feedback: only 2 lines
# [model] Generating content
# [model_node] Generated post:
# **Unlocking the Power of AI and ML: Revolutionizing Business Operations**
#
# As AI and machine learning (ML) continue to transform the business landscape, it's essential to stay ahead of the curve and leverage these technologies to drive growth and innovation.
#
# **Key Takeaways:**
#
# - **Enhanced Decision Making**: AI and ML enable data-driven insights, empowering businesses to make informed decisions and stay competitive.
# - **Increased Efficiency**: Automate routine tasks, streamline processes, and boost productivity with intelligent tools and algorithms.
#
# **Start your AI and ML journey today and discover the endless possibilities!**
#
#  Share your thoughts on how AI and ML are shaping your industry. Let's connect and explore the future of business together! #AI #ML #BusinessInnovation #DigitalTransformation
#
#
#  [human_node] awaiting human feedback...
#
#  [human_node] awaiting human feedback...
# [human_node] Received human feedback: done
#
# [end_node] Process finished
# Final Generated Post: content="**Unlocking the Power of AI and ML: Revolutionizing Business Operations**\n\nAs AI and machine learning (ML) continue to transform the business landscape, it's essential to stay ahead of the curve and leverage these technologies to drive growth and innovation.\n\n**Key Takeaways:**\n\n- **Enhanced Decision Making**: AI and ML enable data-driven insights, empowering businesses to make informed decisions and stay competitive.\n- **Increased Efficiency**: Automate routine tasks, streamline processes, and boost productivity with intelligent tools and algorithms.\n\n**Start your AI and ML journey today and discover the endless possibilities!**\n\n Share your thoughts on how AI and ML are shaping your industry. Let's connect and explore the future of business together! #AI #ML #BusinessInnovation #DigitalTransformation" additional_kwargs={} response_metadata={} id='e7d02e39-522c-4226-ac40-be250b3e3ada'
# Final Human Feedback [HumanMessage(content='make it short', additional_kwargs={}, response_metadata={}, id='4a9f526d-ee96-4e66-a6ef-c4fc6250a36c'), HumanMessage(content='make it short', additional_kwargs={}, response_metadata={}, id='c7b63c41-cfe9-4e0c-9535-bd7172e180d0'), HumanMessage(content='only 2 lines', additional_kwargs={}, response_metadata={}, id='163b86c1-9b5a-4248-bccc-df3307068549'), HumanMessage(content='Finalised', additional_kwargs={}, response_metadata={}, id='955dbc83-998a-4ed4-8fc4-1955f5322b20')]
